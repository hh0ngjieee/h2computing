# %% [markdown]
# **2**&nbsp;&nbsp;&nbsp;For this question you are provided with three text files, each contains a valid list of positive integers, one per line:
#
# - `TEN.txt` has 10 lines
# - `HUNDRED.txt` has 100 lines
# - `THOUSAND.txt` has 1000 lines.
#
# For each of the sub-tasks, add a comment statement at the beginning of the code using the hash symbol '#' to indicate the sub-task the program code belongs to, for example:
#
# ```
# In [1] : # Task 2.1
#          Program code
#
#          Output:
# ```

# %% [markdown]
# **Task 2.1**
#
# Write a function `task2_1(filename)` that:
#
# - takes a string `filename` which represents the name of a text file
# - reads in the contents of the text file
# - returns the content as a list of integers. **[3]**
#
# Call your function `task2_1` with the file `TEN.txt`, printing the returned list and its length, using the following statements:
#
# ```
# result = task2_1('TEN.txt')
# print(result)
# print(len(result))
# ```
#
# **[2]**

# %%
# Task 2.1

def task2_1(filename):

    list_of_integers = []

    #read file and output data, file automatically closes
    with open(filename, 'r') as file:
        for line in file:
            line = line.strip()
            list_of_integers.append(int(line))

    return list_of_integers

#main program
result = task2_1('TEN.txt')
print(result)
print(len(result))
# Out:
# [1636, 3555, 3006, 653, 1665, 3865, 1447, 2568, 619, 2029]
# 10

# %% [markdown]
# **Task 2.2**
#
# One method of sorting is the insertion sort.
#
# Write a function `task2_2(list_of_integers)` that:
#
# - takes a list of integers
# - implements an insertion sort algorithm
# - returns the sorted list of integers. **[5]**
#
# Call your function `task2_2` with the contents of the file `TEN.txt`, printing the returned list, for example, using the following statement:
#
# `print(task2_2(task2_1('TEN.txt')))` **[1]**

# %%
# Task 2.2
def task2_2(list_of_integers):

    for i in range(len(list_of_integers)):
        j = i
        while j > 0 and list_of_integers[j] < list_of_integers[j-1]:
            list_of_integers[j], list_of_integers[j-1] = list_of_integers[j-1], list_of_integers[j]
            j = j - 1

    return list_of_integers

print(task2_2(task2_1('TEN.txt')))
# Out:
# [619, 653, 1447, 1636, 1665, 2029, 2568, 3006, 3555, 3865]

# %% [markdown]
# **Task 2.3**
#
# Another method of sorting is the quicksort.
#
# Write a function `task2_3(list_of_integers)` that:
#
# - takes a list of integers
# - implements a quicksort algorithm
# - returns the sorted list of integers. **[7]**
#
# Call your function `task2_3` with the contents of the file `TEN.txt`, printing the returned list, for example, using the following statement:
#
# `print(task2_3(task2_1('TEN.txt')))` **[1]**

# %%
# Task 2.3
def task2_3(list_of_integers):

    if len(list_of_integers) <= 1: #base case
        return list_of_integers

    i = 0 #original i value
    j = len(list_of_integers) - 2
    pivot = len(list_of_integers) - 1

    while i <= j:

        while list_of_integers[i] < list_of_integers[pivot]:
            i += 1
    
        while list_of_integers[j] > list_of_integers[pivot]:
            j -= 1

        if i <= j: #confirmation that i is infact less than j
            if list_of_integers[i] >= list_of_integers[j]:
                list_of_integers[i], list_of_integers[j] = list_of_integers[j], list_of_integers[i] #swap
                i += 1
                j -= 1

    if list_of_integers[i] >= list_of_integers[pivot]:
        list_of_integers[pivot], list_of_integers[i] = list_of_integers[i], list_of_integers[pivot]

    list_of_integers[:i] = task2_3(list_of_integers[:i]) #keep iterating the left side first
    list_of_integers[i+1:] = quick_sort(list_of_integers[i+1:]) #then target the right side

    return list_of_integers

print(task2_2(task2_1('TEN.txt')))
# Out:
# [619, 653, 1447, 1636, 1665, 2029, 2568, 3006, 3555, 3865]

# %% [markdown]
# **Task 2.4**
#
# The `timeit` library is built into Python and can be used to time simple function calls. Example code is shown in `Task2_timing.py`. (The sample code assumes that it has access to the `task2_2` function.)
#
# Using the `timeit` module, or other evidence, and the three text files provided with this question, compare and contrast, including mention of orders of growth, the time complexity of the insertion sort and quicksort algorithms. **[5]**

# %%
# Task 2.4
import timeit 

t10 = task2_1('TEN.txt')
t100 = task2_1('HUNDRED.txt')
t1000 = task2_1('THOUSAND.txt')

time10 = timeit.timeit(lambda: task2_2(t10), number=1)
time100 = timeit.timeit(lambda: task2_2(t100), number=1)
time1000 = timeit.timeit(lambda: task2_2(t1000), number=1)

ttime10 = timeit.timeit(lambda: task2_3(t10), number=1)
ttime100 = timeit.timeit(lambda: task2_3(t100), number=1)
ttime1000 = timeit.timeit(lambda: task2_3(t1000), number=1)

print(time10)
print(time100)
print(time1000)
print(ttime10)
print(ttime100)
print(ttime1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 12
#       9 time100 = timeit.timeit(lambda: task2_2(t100), number=1)
#      10 time1000 = timeit.timeit(lambda: task2_2(t1000), number=1)
# ---> 12 ttime10 = timeit.timeit(lambda: task2_3(t10), number=1)
#      13 ttime100 = timeit.timeit(lambda: task2_3(t100), number=1)
#      14 ttime1000 = timeit.timeit(lambda: task2_3(t1000), number=1)
#
# File ~\anaconda3\Lib\timeit.py:237, in timeit(stmt, setup, timer, number, globals)
#     234 def timeit(stmt="pass", setup="pass", timer=default_timer,
#     235            number=default_number, globals=None):
#     236     """Convenience function to create Timer object and call timeit method."""
# --> 237     return Timer(stmt, setup, timer, globals).timeit(number)
#
# File ~\anaconda3\Lib\timeit.py:180, in Timer.timeit(self, number)
#     178 gc.disable()
#     179 try:
# --> 180     timing = self.inner(it, self.timer)
#     181 finally:
#     182     if gcold:
#
# File <timeit-src>:6, in inner(_it, _timer, _stmt)
#
# Cell In[9], line 12, in <lambda>()
#       9 time100 = timeit.timeit(lambda: task2_2(t100), number=1)
#      10 time1000 = timeit.timeit(lambda: task2_2(t1000), number=1)
# ---> 12 ttime10 = timeit.timeit(lambda: task2_3(t10), number=1)
#      13 ttime100 = timeit.timeit(lambda: task2_3(t100), number=1)
#      14 ttime1000 = timeit.timeit(lambda: task2_3(t1000), number=1)
#
# Cell In[7], line 28, in task2_3(list_of_integers)
#      25 if list_of_integers[i] >= list_of_integers[pivot]:
#      26     list_of_integers[pivot], list_of_integers[i] = list_of_integers[i], list_of_integers[pivot]
# ---> 28 list_of_integers[:i] = quick_sort(list_of_integers[:i]) #keep iterating the left side first
#      29 list_of_integers[i+1:] = quick_sort(list_of_integers[i+1:]) #then target the right side
#      31 return list_of_integers
#
# NameError: name 'quick_sort' is not defined

# %% [markdown]
# Save your Jupyter notebook for Task 2.
